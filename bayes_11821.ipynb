# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
datalatih = pd.read_excel("data testing.xlsx")
datalatih.head(11)
# Out:
#              Jurusan  Matematika  Bahasa Inggris  Bahasa Indonesia  \
# 0         Matematika          98              98                98
# 1         Matematika          80              76                65
# 2     Sastra Inggris          62              77                82
# 3         Matematika          83              82                75
# 4     Sastra Inggris          96              75                68
# 5         Matematika          91              83                84
# 6   Sastra Indonesia          88              80                90
# 7   Sastra Indonesia          84              82                88
# 8     Sastra Inggris          79              89                85
# 9     Sastra Inggris          83              88                81
# 10    Sastra Inggris          82              85                84
#
#     Prestasi Siswa  Prestasi Sekolah
# 0                3                 1
# 1                1                 2
# 2                2                 1
# 3                1                 1
# 4                1                 1
# 5                2                 2
# 6                2                 1
# 7                1                 1
# 8                1                 1
# 9                2                 2
# 10               2                 1

# %%
datalatih.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11 entries, 0 to 10
# Data columns (total 6 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Jurusan           11 non-null     object
#  1   Matematika        11 non-null     int64
#  2   Bahasa Inggris    11 non-null     int64
#  3   Bahasa Indonesia  11 non-null     int64
#  4   Prestasi Siswa    11 non-null     int64
#  5   Prestasi Sekolah  11 non-null     int64
# dtypes: int64(5), object(1)
# memory usage: 656.0+ bytes

# %%
from sklearn.cluster import KMeans
plt.scatter(datalatih.Matematika, datalatih.Jurusan, s = 75, c = "c", marker = "o", alpha = 0.5)
plt.show()

# %%
x = datalatih.drop(["Jurusan"], axis=1)
x.head(11)
# Out:
#     Matematika  Bahasa Inggris  Bahasa Indonesia  Prestasi Siswa  \
# 0           98              98                98               3
# 1           80              76                65               1
# 2           62              77                82               2
# 3           83              82                75               1
# 4           96              75                68               1
# 5           91              83                84               2
# 6           88              80                90               2
# 7           84              82                88               1
# 8           79              89                85               1
# 9           83              88                81               2
# 10          82              85                84               2
#
#     Prestasi Sekolah
# 0                  1
# 1                  2
# 2                  1
# 3                  1
# 4                  1
# 5                  2
# 6                  1
# 7                  1
# 8                  1
# 9                  2
# 10                 1

# %%
y = datalatih["Jurusan"]
y.head(11)
# Out:
# 0           Matematika
# 1           Matematika
# 2       Sastra Inggris
# 3           Matematika
# 4       Sastra Inggris
# 5           Matematika
# 6     Sastra Indonesia
# 7     Sastra Indonesia
# 8       Sastra Inggris
# 9       Sastra Inggris
# 10      Sastra Inggris
# Name: Jurusan, dtype: object

# %%
from sklearn.model_selection import train_test_split

from sklearn.naive_bayes import GaussianNB

modelnb = GaussianNB()

nbtrain = modelnb.fit(x, y)
datauji = pd.read_excel("data testing.xlsx")
datauji.head(11)
# Out:
#              Jurusan  Matematika  Bahasa Inggris  Bahasa Indonesia  \
# 0         Matematika          98              98                98
# 1         Matematika          80              76                65
# 2     Sastra Inggris          62              77                82
# 3         Matematika          83              82                75
# 4     Sastra Inggris          96              75                68
# 5         Matematika          91              83                84
# 6   Sastra Indonesia          88              80                90
# 7   Sastra Indonesia          84              82                88
# 8     Sastra Inggris          79              89                85
# 9     Sastra Inggris          83              88                81
# 10    Sastra Inggris          82              85                84
#
#     Prestasi Siswa  Prestasi Sekolah
# 0                3                 1
# 1                1                 2
# 2                2                 1
# 3                1                 1
# 4                1                 1
# 5                2                 2
# 6                2                 1
# 7                1                 1
# 8                1                 1
# 9                2                 2
# 10               2                 1

# %%
from sklearn.model_selection import train_test_split

from sklearn.naive_bayes import GaussianNB

modelnb = GaussianNB()

nbtrain = modelnb.fit(x, y)
datauji = pd.read_excel("data testing.xlsx")
datauji.head(11)
# Out:
#              Jurusan  Matematika  Bahasa Inggris  Bahasa Indonesia  \
# 0         Matematika          98              98                98
# 1         Matematika          80              76                65
# 2     Sastra Inggris          62              77                82
# 3         Matematika          83              82                75
# 4     Sastra Inggris          96              75                68
# 5         Matematika          91              83                84
# 6   Sastra Indonesia          88              80                90
# 7   Sastra Indonesia          84              82                88
# 8     Sastra Inggris          79              89                85
# 9     Sastra Inggris          83              88                81
# 10    Sastra Inggris          82              85                84
#
#     Prestasi Siswa  Prestasi Sekolah
# 0                3                 1
# 1                1                 2
# 2                2                 1
# 3                1                 1
# 4                1                 1
# 5                2                 2
# 6                2                 1
# 7                1                 1
# 8                1                 1
# 9                2                 2
# 10               2                 1

# %%
y_uji = datauji["Jurusan"]
y_uji.head(11)
# Out:
# 0           Matematika
# 1           Matematika
# 2       Sastra Inggris
# 3           Matematika
# 4       Sastra Inggris
# 5           Matematika
# 6     Sastra Indonesia
# 7     Sastra Indonesia
# 8       Sastra Inggris
# 9       Sastra Inggris
# 10      Sastra Inggris
# Name: Jurusan, dtype: object

# %%
Y_predict = nbtrain.predict(x_test)
print("Prediksi Naive Bayes : ",Y_predict)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-11-140e962618c3> in <module>()
# ----> 1 Y_predict = nbtrain.predict(x_test)
#       2 print("Prediksi Naive Bayes : ",Y_predict)
#
# NameError: name 'x_test' is not defined

# %%
from sklearn.metrics import accuracy_score
accuracy= accuracy_score(y_uji, Y_predict)
print("Akurasi Naive Bayes : ",accuracy)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-12-3c66a77b1537> in <module>()
#       1 from sklearn.metrics import accuracy_score
# ----> 2 accuracy= accuracy_score(y_uji, Y_predict)
#       3 print("Akurasi Naive Bayes : ",accuracy)
#
# NameError: name 'Y_predict' is not defined

# %%
from sklearn.metrics import classification_report
print(classification_report(y_uji, Y_predict))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-13-3c1773698f25> in <module>()
#       1 from sklearn.metrics import classification_report
# ----> 2 print(classification_report(y_uji, Y_predict))
#
# NameError: name 'Y_predict' is not defined
